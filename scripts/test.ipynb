# %%
import pandas as pd

df = pd.read_csv("../data/cleaned.csv")
df
# Out:
#         host_since  host_response_time  host_response_rate host_is_superhost  \
# 0       2010-01-08      within an hour               100.0                 f
# 1       2010-03-26             unknown                 0.0                 f
# 2       2010-04-03  within a few hours               100.0                 f
# 3       2010-05-31      within an hour               100.0                 t
# 4       2010-06-27      within an hour               100.0                 f
# ...            ...                 ...                 ...               ...
# 379634  2017-04-23  within a few hours               100.0                 f
# 379635  2018-01-23  within a few hours               100.0                 f
# 379636  2019-04-28      within an hour               100.0                 f
# 379637  2017-12-26  within a few hours               100.0                 f
# 379638  2018-10-22      within an hour               100.0                 t
#
# ...

# %%
df["amenities"].str.len().max()
# Out:
# 1382.0

# %%
df[df["amenities"].isna()]
# Out:
#         host_since  host_response_time  host_response_rate host_is_superhost  \
# 345     2012-12-02      within an hour                94.0                 f
# 452     2012-12-02      within an hour                94.0                 f
# 1000    2012-10-29        within a day                77.0                 f
# 1661    2013-12-09        within a day                75.0                 f
# 2580    2013-08-07  within a few hours               100.0                 f
# ...            ...                 ...                 ...               ...
# 371161  2012-11-26      within an hour               100.0                 t
# 373412  2018-09-10             unknown                 0.0                 f
# 376397  2012-05-21        within a day               100.0                 t
# 377354  2016-05-29             unknown                 0.0                 f
# 379068  2011-09-28      within an hour                83.0                 f
#
# ...
